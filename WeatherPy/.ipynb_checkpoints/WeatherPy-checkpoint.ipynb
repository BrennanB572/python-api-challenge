# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 572

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = 'http://api.openweathermap.org/data/2.5/weather'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?q={city}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        res = requests.get(city_url)
        city_weather = res.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | avarua
# Processing Record 2 of Set 1 | grytviken
# Processing Record 3 of Set 1 | leava
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | port-aux-francais
# Processing Record 6 of Set 1 | college
# Processing Record 7 of Set 1 | puerto natales
# Processing Record 8 of Set 1 | natitingou
# Processing Record 9 of Set 1 | vorgashor
# Processing Record 10 of Set 1 | praia da vitoria
# Processing Record 11 of Set 1 | aroma
# Processing Record 12 of Set 1 | broome
# Processing Record 13 of Set 1 | enewetak
# Processing Record 14 of Set 1 | atafu village
# Processing Record 15 of Set 1 | iqaluit
# Processing Record 16 of Set 1 | nove zamky
# Processing Record 17 of Set 1 | anadyr
# Processing Record 18 of Set 1 | bethel
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | kyrenia
# Processing Record 21 of Set 1 | caleta de carquin
# Processing Record 22 of Set 1 | edinburgh of the seven seas
# Processing Record 23 of Set 1 | stettler
# Processing Record 24 of Set 1 | antalaha
# Processing Record 25 of Set 1 | tanjung selor
# City not found. Skipping...
# Processing Record 26 of Set 1 | longyearbyen
# Processing Record 27 of Set 1 | adamstown
# Processing Record 28 of Set 1 | badger
# Processing Record 29 of Set 1 | bilibino
# Processing Record 30 of Set 1 | zykovo
# Processing Record 31 of Set 1 | xining
# Processing Record 32 of Set 1 | port mathurin
# Processing Record 33 of Set 1 | waitangi
# Processing Record 34 of Set 1 | taulaga
# Processing Record 35 of Set 1 | west island
# Processing Record 36 of Set 1 | brookings
# Processing Record 37 of Set 1 | kenai
# Processing Record 38 of Set 1 | glace bay
# Processing Record 39 of Set 1 | pekan
# Processing Record 40 of Set 1 | cannonvale
# Processing Record 41 of Set 1 | hithadhoo
# Processing Record 42 of Set 1 | papatowai
# Processing Record 43 of Set 1 | timbuktu
# Processing Record 44 of Set 1 | whitehorse
# Processing Record 45 of Set 1 | lebu
# Processing Record 46 of Set 1 | walvis bay
# Processing Record 47 of Set 1 | muisne
# Processing Record 48 of Set 1 | antsiranana
# Processing Record 49 of Set 1 | yorkton
# Processing Record 50 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 0 of Set 2 | stanley
# Processing Record 1 of Set 2 | rio turbio
# City not found. Skipping...
# Processing Record 2 of Set 2 | dongola
# Processing Record 3 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 4 of Set 2 | el nido
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | udachny
# Processing Record 7 of Set 2 | valparaiso
# Processing Record 8 of Set 2 | port saint john's
# Processing Record 9 of Set 2 | namibe
# Processing Record 10 of Set 2 | hawaiian paradise park
# Processing Record 11 of Set 2 | invercargill
# Processing Record 12 of Set 2 | blackmans bay
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | sevilla la nueva
# Processing Record 15 of Set 2 | nova sintra
# Processing Record 16 of Set 2 | haiku-pauwela
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | princeville
# Processing Record 19 of Set 2 | ilulissat
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | waingapu
# Processing Record 22 of Set 2 | ceeldheer
# Processing Record 23 of Set 2 | constantina
# Processing Record 24 of Set 2 | altar
# Processing Record 25 of Set 2 | las khorey
# Processing Record 26 of Set 2 | bamboo flat
# Processing Record 27 of Set 2 | betio village
# Processing Record 28 of Set 2 | talnakh
# Processing Record 29 of Set 2 | carnarvon
# Processing Record 30 of Set 2 | paracuru
# Processing Record 31 of Set 2 | ribeira grande
# Processing Record 32 of Set 2 | crane
# Processing Record 33 of Set 2 | coquimbo
# Processing Record 34 of Set 2 | thompson
# Processing Record 35 of Set 2 | lompoc
# Processing Record 36 of Set 2 | chonchi
# Processing Record 37 of Set 2 | constantia
# Processing Record 38 of Set 2 | lihue
# Processing Record 39 of Set 2 | sikka
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | teyateyaneng
# Processing Record 42 of Set 2 | ust-nera
# Processing Record 43 of Set 2 | saipan
# Processing Record 44 of Set 2 | lagoa
# Processing Record 45 of Set 2 | qui nhon
# Processing Record 46 of Set 2 | murmashi
# Processing Record 47 of Set 2 | ribeira brava
# Processing Record 48 of Set 2 | christchurch
# Processing Record 49 of Set 2 | hamilton
# Processing Record 0 of Set 3 | greymouth
# Processing Record 1 of Set 3 | juba
# Processing Record 2 of Set 3 | lazaro cardenas
# Processing Record 3 of Set 3 | whakatane
# Processing Record 4 of Set 3 | monrovia
# Processing Record 5 of Set 3 | mhangura
# Processing Record 6 of Set 3 | kerikeri
# Processing Record 7 of Set 3 | st. john's
# Processing Record 8 of Set 3 | sur
# Processing Record 9 of Set 3 | marka
# Processing Record 10 of Set 3 | kismayo
# Processing Record 11 of Set 3 | cargados carajos
# City not found. Skipping...
# Processing Record 12 of Set 3 | gadzhiyevo
# Processing Record 13 of Set 3 | safi
# Processing Record 14 of Set 3 | mangrol
# Processing Record 15 of Set 3 | eatonton
# Processing Record 16 of Set 3 | tiksi
# Processing Record 17 of Set 3 | kandi
# Processing Record 18 of Set 3 | shakawe
# Processing Record 19 of Set 3 | new norfolk
# Processing Record 20 of Set 3 | bhusaval
# Processing Record 21 of Set 3 | karagay
# Processing Record 22 of Set 3 | tura
# Processing Record 23 of Set 3 | tralee
# Processing Record 24 of Set 3 | hoxtolgay
# City not found. Skipping...
# Processing Record 25 of Set 3 | olonkinbyen
# Processing Record 26 of Set 3 | kavieng
# Processing Record 27 of Set 3 | manta
# Processing Record 28 of Set 3 | kodiak
# Processing Record 29 of Set 3 | pisco
# Processing Record 30 of Set 3 | palikir - national government center
# Processing Record 31 of Set 3 | goroka
# Processing Record 32 of Set 3 | nema
# Processing Record 33 of Set 3 | ortega
# Processing Record 34 of Set 3 | alice springs
# Processing Record 35 of Set 3 | burang
# Processing Record 36 of Set 3 | el fasher
# Processing Record 37 of Set 3 | novaya igirma
# Processing Record 38 of Set 3 | hollola
# Processing Record 39 of Set 3 | vila franca do campo
# Processing Record 40 of Set 3 | fuvahmulah
# City not found. Skipping...
# Processing Record 41 of Set 3 | savja
# City not found. Skipping...
# Processing Record 42 of Set 3 | grand-bourg
# Processing Record 43 of Set 3 | birni n konni
# Processing Record 44 of Set 3 | buckeye
# Processing Record 45 of Set 3 | punta arenas
# Processing Record 46 of Set 3 | baoqing
# Processing Record 47 of Set 3 | khandyga
# Processing Record 48 of Set 3 | kingston
# Processing Record 49 of Set 3 | samus'
# Processing Record 0 of Set 4 | port douglas
# Processing Record 1 of Set 4 | uturoa
# Processing Record 2 of Set 4 | north bend
# Processing Record 3 of Set 4 | bournemouth
# Processing Record 4 of Set 4 | aasiaat
# Processing Record 5 of Set 4 | margaret river
# Processing Record 6 of Set 4 | rovinj
# Processing Record 7 of Set 4 | yeed
# Processing Record 8 of Set 4 | copiapo
# Processing Record 9 of Set 4 | villa gesell
# Processing Record 10 of Set 4 | san julian
# Processing Record 11 of Set 4 | pekalongan
# Processing Record 12 of Set 4 | forest city
# Processing Record 13 of Set 4 | kalach-na-donu
# Processing Record 14 of Set 4 | revda
# Processing Record 15 of Set 4 | nadi
# Processing Record 16 of Set 4 | miquelon
# Processing Record 17 of Set 4 | mufumbwe
# Processing Record 18 of Set 4 | acarau
# Processing Record 19 of Set 4 | flying fish cove
# Processing Record 20 of Set 4 | touros
# Processing Record 21 of Set 4 | balqash
# Processing Record 22 of Set 4 | isafjordur
# Processing Record 23 of Set 4 | eirunepe
# Processing Record 24 of Set 4 | koutiala
# Processing Record 25 of Set 4 | kalmunai
# Processing Record 26 of Set 4 | dudinka
# Processing Record 27 of Set 4 | taroa
# Processing Record 28 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 29 of Set 4 | kempsey
# Processing Record 30 of Set 4 | puerto cabezas
# Processing Record 31 of Set 4 | pangoa
# Processing Record 32 of Set 4 | zaozersk
# Processing Record 33 of Set 4 | yanchep
# Processing Record 34 of Set 4 | sherbakul'
# Processing Record 35 of Set 4 | vadso
# Processing Record 36 of Set 4 | tofol
# Processing Record 37 of Set 4 | hobyo
# Processing Record 38 of Set 4 | gizo
# Processing Record 39 of Set 4 | alo
# Processing Record 40 of Set 4 | tazovsky
# Processing Record 41 of Set 4 | vryheid
# Processing Record 42 of Set 4 | hermanus
# Processing Record 43 of Set 4 | belyy yar
# Processing Record 44 of Set 4 | utrik
# Processing Record 45 of Set 4 | moyale
# Processing Record 46 of Set 4 | scottburgh
# Processing Record 47 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 48 of Set 4 | bubaque
# Processing Record 49 of Set 4 | nemuro
# Processing Record 0 of Set 5 | luderitz
# Processing Record 1 of Set 5 | gorontalo
# Processing Record 2 of Set 5 | la libertad
# Processing Record 3 of Set 5 | pontianak
# Processing Record 4 of Set 5 | sinabang
# Processing Record 5 of Set 5 | taitung city
# Processing Record 6 of Set 5 | taoudenni
# Processing Record 7 of Set 5 | kyren
# Processing Record 8 of Set 5 | beberibe
# Processing Record 9 of Set 5 | ancud
# Processing Record 10 of Set 5 | karratha
# Processing Record 11 of Set 5 | cape coast
# Processing Record 12 of Set 5 | calabozo
# Processing Record 13 of Set 5 | ntoum
# Processing Record 14 of Set 5 | puerto carreno
# Processing Record 15 of Set 5 | polyarnyy
# Processing Record 16 of Set 5 | al muwayh
# Processing Record 17 of Set 5 | luz
# Processing Record 18 of Set 5 | fale old settlement
# Processing Record 19 of Set 5 | kruisfontein
# Processing Record 20 of Set 5 | klyuchi
# Processing Record 21 of Set 5 | trekhgornyy
# Processing Record 22 of Set 5 | ivdel'
# Processing Record 23 of Set 5 | we
# City not found. Skipping...
# Processing Record 24 of Set 5 | nefta
# Processing Record 25 of Set 5 | phu khiao
# Processing Record 26 of Set 5 | adre
# Processing Record 27 of Set 5 | sayansk
# Processing Record 28 of Set 5 | sosnogorsk
# Processing Record 29 of Set 5 | cedral
# Processing Record 30 of Set 5 | felidhoo
# City not found. Skipping...
# Processing Record 31 of Set 5 | brandon
# Processing Record 32 of Set 5 | malvan
# Processing Record 33 of Set 5 | xinguara
# City not found. Skipping...
# Processing Record 34 of Set 5 | springs
# Processing Record 35 of Set 5 | phan thiet
# Processing Record 36 of Set 5 | taltal
# Processing Record 37 of Set 5 | porto murtinho
# Processing Record 38 of Set 5 | ramapuram
# Processing Record 39 of Set 5 | las heras
# Processing Record 40 of Set 5 | guerrero negro
# Processing Record 41 of Set 5 | harstad
# Processing Record 42 of Set 5 | luwuk
# Processing Record 43 of Set 5 | alofi
# Processing Record 44 of Set 5 | kristiansund
# Processing Record 45 of Set 5 | serhetabat
# Processing Record 46 of Set 5 | mary
# Processing Record 47 of Set 5 | juneau
# Processing Record 48 of Set 5 | afaahiti
# Processing Record 49 of Set 5 | saint-pierre
# Processing Record 0 of Set 6 | new plymouth
# Processing Record 1 of Set 6 | gamba
# Processing Record 2 of Set 6 | prado
# Processing Record 3 of Set 6 | holualoa
# Processing Record 4 of Set 6 | halifax
# Processing Record 5 of Set 6 | ndikinimeki
# Processing Record 6 of Set 6 | kapuskasing
# Processing Record 7 of Set 6 | puerto baquerizo moreno
# Processing Record 8 of Set 6 | portland
# Processing Record 9 of Set 6 | hanzhong
# Processing Record 10 of Set 6 | yoloten
# Processing Record 11 of Set 6 | okulovka
# Processing Record 12 of Set 6 | puerto escondido
# Processing Record 13 of Set 6 | qaqortoq
# Processing Record 14 of Set 6 | salalah
# Processing Record 15 of Set 6 | en naqoura
# City not found. Skipping...
# Processing Record 16 of Set 6 | beaumont
# Processing Record 17 of Set 6 | lang son
# Processing Record 18 of Set 6 | east london
# Processing Record 19 of Set 6 | six-fours-les-plages
# Processing Record 20 of Set 6 | coos bay
# Processing Record 21 of Set 6 | kuanda
# Processing Record 22 of Set 6 | thief river falls
# Processing Record 23 of Set 6 | weno
# Processing Record 24 of Set 6 | wenling
# Processing Record 25 of Set 6 | kabala
# Processing Record 26 of Set 6 | el calafate
# Processing Record 27 of Set 6 | kyosai
# Processing Record 28 of Set 6 | lewistown
# Processing Record 29 of Set 6 | costa calma
# City not found. Skipping...
# Processing Record 30 of Set 6 | kryzhopil'
# City not found. Skipping...
# Processing Record 31 of Set 6 | itamarandiba
# Processing Record 32 of Set 6 | mejit
# Processing Record 33 of Set 6 | alapa
# Processing Record 34 of Set 6 | pergamino
# Processing Record 35 of Set 6 | andergrove
# Processing Record 36 of Set 6 | anar darah
# Processing Record 37 of Set 6 | pante makasar
# City not found. Skipping...
# Processing Record 38 of Set 6 | revelstoke
# Processing Record 39 of Set 6 | nuuk
# Processing Record 40 of Set 6 | isle of lewis
# City not found. Skipping...
# Processing Record 41 of Set 6 | wailua homesteads
# Processing Record 42 of Set 6 | krasnokamensk
# Processing Record 43 of Set 6 | diu
# Processing Record 44 of Set 6 | kataragama
# City not found. Skipping...
# Processing Record 45 of Set 6 | ljungby
# Processing Record 46 of Set 6 | faya-largeau
# Processing Record 47 of Set 6 | tanki leendert
# City not found. Skipping...
# Processing Record 48 of Set 6 | xilin hot
# Processing Record 49 of Set 6 | visby
# Processing Record 0 of Set 7 | brest
# Processing Record 1 of Set 7 | den helder
# Processing Record 2 of Set 7 | hasaki
# Processing Record 3 of Set 7 | yunyang
# Processing Record 4 of Set 7 | madang
# Processing Record 5 of Set 7 | hadibu
# Processing Record 6 of Set 7 | tomatlan
# Processing Record 7 of Set 7 | weining
# Processing Record 8 of Set 7 | arenapolis
# Processing Record 9 of Set 7 | stansbury park
# Processing Record 10 of Set 7 | pacific grove
# Processing Record 11 of Set 7 | kapa'a
# Processing Record 12 of Set 7 | camapua
# Processing Record 13 of Set 7 | duncan town
# City not found. Skipping...
# Processing Record 14 of Set 7 | puerto madryn
# Processing Record 15 of Set 7 | shubarshi
# Processing Record 16 of Set 7 | fukuecho
# Processing Record 17 of Set 7 | bayan nur
# City not found. Skipping...
# Processing Record 18 of Set 7 | cockburn town
# Processing Record 19 of Set 7 | khovd
# Processing Record 20 of Set 7 | port hedland
# Processing Record 21 of Set 7 | obo
# Processing Record 22 of Set 7 | petrolina
# Processing Record 23 of Set 7 | tobi village
# City not found. Skipping...
# Processing Record 24 of Set 7 | colares
# Processing Record 25 of Set 7 | siatista
# Processing Record 26 of Set 7 | bambari
# Processing Record 27 of Set 7 | port elizabeth
# Processing Record 28 of Set 7 | kotel'nikovo
# Processing Record 29 of Set 7 | urucara
# Processing Record 30 of Set 7 | karauli
# Processing Record 31 of Set 7 | bardai
# Processing Record 32 of Set 7 | jimenez
# Processing Record 33 of Set 7 | sofifi
# City not found. Skipping...
# Processing Record 34 of Set 7 | torquay
# Processing Record 35 of Set 7 | ambon
# Processing Record 36 of Set 7 | chui
# Processing Record 37 of Set 7 | konstantinovka
# Processing Record 38 of Set 7 | mount gambier
# Processing Record 39 of Set 7 | nosy varika
# Processing Record 40 of Set 7 | plainview
# Processing Record 41 of Set 7 | san patricio
# Processing Record 42 of Set 7 | maruoka
# Processing Record 43 of Set 7 | devinuwara
# City not found. Skipping...
# Processing Record 44 of Set 7 | tucumcari
# Processing Record 45 of Set 7 | makushino
# Processing Record 46 of Set 7 | ladario
# Processing Record 47 of Set 7 | krasnovishersk
# Processing Record 48 of Set 7 | roma
# Processing Record 49 of Set 7 | arraial do cabo
# Processing Record 0 of Set 8 | opuwo
# Processing Record 1 of Set 8 | aykhal
# Processing Record 2 of Set 8 | colonia
# Processing Record 3 of Set 8 | ulsteinvik
# Processing Record 4 of Set 8 | tolanaro
# Processing Record 5 of Set 8 | darwin
# Processing Record 6 of Set 8 | khawr fakkan
# Processing Record 7 of Set 8 | galesong
# Processing Record 8 of Set 8 | lasalgaon
# Processing Record 9 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 10 of Set 8 | tsetserleg
# Processing Record 11 of Set 8 | atasu
# Processing Record 12 of Set 8 | maamba
# Processing Record 13 of Set 8 | kununurra
# Processing Record 14 of Set 8 | at taj
# Processing Record 15 of Set 8 | beau vallon
# Processing Record 16 of Set 8 | markovo
# Processing Record 17 of Set 8 | lapy
# Processing Record 18 of Set 8 | terrace
# Processing Record 19 of Set 8 | severo-yeniseyskiy
# Processing Record 20 of Set 8 | inongo
# Processing Record 21 of Set 8 | orchard homes
# Processing Record 22 of Set 8 | necochea
# Processing Record 23 of Set 8 | iskateley
# Processing Record 24 of Set 8 | puerto armuelles
# Processing Record 25 of Set 8 | boundiali
# Processing Record 26 of Set 8 | standerton
# Processing Record 27 of Set 8 | yinchuan
# Processing Record 28 of Set 8 | rondonopolis
# Processing Record 29 of Set 8 | berrahal
# Processing Record 30 of Set 8 | tavistock
# Processing Record 31 of Set 8 | stornoway
# Processing Record 32 of Set 8 | kirensk
# Processing Record 33 of Set 8 | alghero
# Processing Record 34 of Set 8 | vorkuta
# Processing Record 35 of Set 8 | beloyarskiy
# Processing Record 36 of Set 8 | puerto real
# Processing Record 37 of Set 8 | caconda
# Processing Record 38 of Set 8 | happy valley-goose bay
# Processing Record 39 of Set 8 | valley east
# City not found. Skipping...
# Processing Record 40 of Set 8 | saint-joseph
# Processing Record 41 of Set 8 | miri
# Processing Record 42 of Set 8 | floro
# Processing Record 43 of Set 8 | nagqu
# Processing Record 44 of Set 8 | mapastepec
# Processing Record 45 of Set 8 | kavaratti
# Processing Record 46 of Set 8 | teknaf
# Processing Record 47 of Set 8 | biltine
# Processing Record 48 of Set 8 | xam nua
# Processing Record 49 of Set 8 | vingt cinq
# City not found. Skipping...
# Processing Record 0 of Set 9 | cooma
# Processing Record 1 of Set 9 | nizhniy kuranakh
# Processing Record 2 of Set 9 | ust'-kulom
# Processing Record 3 of Set 9 | inari
# Processing Record 4 of Set 9 | san jose
# Processing Record 5 of Set 9 | qarazhal
# Processing Record 6 of Set 9 | bulgan
# Processing Record 7 of Set 9 | vilyuchinsk
# Processing Record 8 of Set 9 | fonte boa
# Processing Record 9 of Set 9 | remire-montjoly
# Processing Record 10 of Set 9 | minas de marcona
# Processing Record 11 of Set 9 | hayma'
# City not found. Skipping...
# Processing Record 12 of Set 9 | chuguyevka
# Processing Record 13 of Set 9 | gemena
# Processing Record 14 of Set 9 | la passe
# Processing Record 15 of Set 9 | aginskoye
# Processing Record 16 of Set 9 | teguise
# Processing Record 17 of Set 9 | berdigestyakh
# Processing Record 18 of Set 9 | snowflake
# Processing Record 19 of Set 9 | howrah
# Processing Record 20 of Set 9 | la gi
# Processing Record 21 of Set 9 | kristinestad
# Processing Record 22 of Set 9 | karasuk
# Processing Record 23 of Set 9 | santa ana
# Processing Record 24 of Set 9 | bangjun
# Processing Record 25 of Set 9 | am timan
# Processing Record 26 of Set 9 | kuta
# Processing Record 27 of Set 9 | broken hill
# Processing Record 28 of Set 9 | ponta delgada
# Processing Record 29 of Set 9 | siyabuswa
# Processing Record 30 of Set 9 | peniche
# Processing Record 31 of Set 9 | olyokminsk
# Processing Record 32 of Set 9 | ust'-uda
# Processing Record 33 of Set 9 | bad segeberg
# Processing Record 34 of Set 9 | san jose de jachal
# Processing Record 35 of Set 9 | yuzhno-kurilsk
# Processing Record 36 of Set 9 | laguna
# Processing Record 37 of Set 9 | magadan
# Processing Record 38 of Set 9 | taber
# Processing Record 39 of Set 9 | lloydminster
# Processing Record 40 of Set 9 | mostaganem
# Processing Record 41 of Set 9 | filey
# Processing Record 42 of Set 9 | lorengau
# Processing Record 43 of Set 9 | lyantor
# Processing Record 44 of Set 9 | capitan bado
# Processing Record 45 of Set 9 | rabo de peixe
# Processing Record 46 of Set 9 | puerto lempira
# Processing Record 47 of Set 9 | gaspe
# Processing Record 48 of Set 9 | abepura
# Processing Record 49 of Set 9 | nikolayevsk-on-amure
# Processing Record 0 of Set 10 | bako
# Processing Record 1 of Set 10 | san luis de la loma
# Processing Record 2 of Set 10 | hammerfest
# Processing Record 3 of Set 10 | nizhniy odes
# Processing Record 4 of Set 10 | challapata
# Processing Record 5 of Set 10 | trondheim
# Processing Record 6 of Set 10 | kourou
# Processing Record 7 of Set 10 | cidreira
# Processing Record 8 of Set 10 | ta`u
# Processing Record 9 of Set 10 | knjazevac
# Processing Record 10 of Set 10 | moengo
# Processing Record 11 of Set 10 | gushu
# Processing Record 12 of Set 10 | belawan
# Processing Record 13 of Set 10 | paraiso
# Processing Record 14 of Set 10 | belmonte
# Processing Record 15 of Set 10 | grand falls-windsor
# Processing Record 16 of Set 10 | wakkanai
# Processing Record 17 of Set 10 | mahbubnagar
# Processing Record 18 of Set 10 | chibougamau
# Processing Record 19 of Set 10 | morondava
# Processing Record 20 of Set 10 | kudymkar
# Processing Record 21 of Set 10 | yangjiang
# Processing Record 22 of Set 10 | saldanha
# Processing Record 23 of Set 10 | lubango
# Processing Record 24 of Set 10 | ugoofaaru
# Processing Record 25 of Set 10 | loiza
# Processing Record 26 of Set 10 | yeppoon
# Processing Record 27 of Set 10 | lively
# Processing Record 28 of Set 10 | kili
# Processing Record 29 of Set 10 | brisas de zicatela
# Processing Record 30 of Set 10 | salahonda
# Processing Record 31 of Set 10 | okhotsk
# Processing Record 32 of Set 10 | hengchun
# Processing Record 33 of Set 10 | podporozh'ye
# Processing Record 34 of Set 10 | tadmur
# Processing Record 35 of Set 10 | shimoda
# Processing Record 36 of Set 10 | concepcion
# Processing Record 37 of Set 10 | ilomantsi
# Processing Record 38 of Set 10 | quthing
# Processing Record 39 of Set 10 | tchibanga
# Processing Record 40 of Set 10 | palmer
# Processing Record 41 of Set 10 | jwaneng
# Processing Record 42 of Set 10 | kharsawan
# Processing Record 43 of Set 10 | prince george
# Processing Record 44 of Set 10 | iwanai
# Processing Record 45 of Set 10 | kangding
# Processing Record 46 of Set 10 | padang
# Processing Record 47 of Set 10 | arvayheer
# Processing Record 48 of Set 10 | aldan
# Processing Record 49 of Set 10 | keflavik
# Processing Record 0 of Set 11 | rio grande
# Processing Record 1 of Set 11 | emerald
# Processing Record 2 of Set 11 | labrador city
# Processing Record 3 of Set 11 | la'ie
# Processing Record 4 of Set 11 | paramonga
# Processing Record 5 of Set 11 | zhicheng
# Processing Record 6 of Set 11 | huarmey
# Processing Record 7 of Set 11 | bathsheba
# Processing Record 8 of Set 11 | haimen
# Processing Record 9 of Set 11 | sanya
# Processing Record 10 of Set 11 | malpica
# Processing Record 11 of Set 11 | yallahs
# Processing Record 12 of Set 11 | codrington
# Processing Record 13 of Set 11 | cabo san lucas
# Processing Record 14 of Set 11 | kasama
# Processing Record 15 of Set 11 | spartanburg
# Processing Record 16 of Set 11 | rongelap
# Processing Record 17 of Set 11 | bartlesville
# Processing Record 18 of Set 11 | slavgorod
# Processing Record 19 of Set 11 | merizo village
# Processing Record 20 of Set 11 | kolonia
# Processing Record 21 of Set 11 | djibo
# Processing Record 22 of Set 11 | arkhangel'sk
# Processing Record 23 of Set 11 | tianpeng
# Processing Record 24 of Set 11 | fisterra
# Processing Record 25 of Set 11 | mili
# Processing Record 26 of Set 11 | lipova
# Processing Record 27 of Set 11 | okha
# Processing Record 28 of Set 11 | queenstown
# Processing Record 29 of Set 11 | aniva
# Processing Record 30 of Set 11 | barabai
# Processing Record 31 of Set 11 | mashhad
# Processing Record 32 of Set 11 | luorong
# Processing Record 33 of Set 11 | sucua
# Processing Record 34 of Set 11 | chala
# Processing Record 35 of Set 11 | zanesville
# Processing Record 36 of Set 11 | khanty-mansiysk
# Processing Record 37 of Set 11 | pasni
# Processing Record 38 of Set 11 | santa quiteria
# Processing Record 39 of Set 11 | mizdah
# Processing Record 40 of Set 11 | eyl
# Processing Record 41 of Set 11 | mokhotlong
# Processing Record 42 of Set 11 | padang mat sirat
# City not found. Skipping...
# Processing Record 43 of Set 11 | masterton
# Processing Record 44 of Set 11 | kudahuvadhoo
# Processing Record 45 of Set 11 | souillac
# Processing Record 46 of Set 11 | ar ruways
# Processing Record 47 of Set 11 | thurso
# Processing Record 48 of Set 11 | klaksvik
# Processing Record 49 of Set 11 | las lomitas
# Processing Record 0 of Set 12 | sungai besar
# Processing Record 1 of Set 12 | sivrice
# Processing Record 2 of Set 12 | inhambane
# Processing Record 3 of Set 12 | sakakah
# Processing Record 4 of Set 12 | schonheide
# City not found. Skipping...
# Processing Record 5 of Set 12 | sant lluis
# Processing Record 6 of Set 12 | vetluga
# Processing Record 7 of Set 12 | muscatine
# Processing Record 8 of Set 12 | pryluky
# Processing Record 9 of Set 12 | bargaal
# Processing Record 10 of Set 12 | howard springs
# Processing Record 11 of Set 12 | ardabil
# Processing Record 12 of Set 12 | egilsstadir
# Processing Record 13 of Set 12 | mulino
# Processing Record 14 of Set 12 | riverton
# Processing Record 15 of Set 12 | porto novo
# Processing Record 16 of Set 12 | padegan-e manjil
# City not found. Skipping...
# Processing Record 17 of Set 12 | aweil
# Processing Record 18 of Set 12 | daru
# Processing Record 19 of Set 12 | port blair
# Processing Record 20 of Set 12 | hami
# Processing Record 21 of Set 12 | goldap
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          541
# Lat           541
# Lng           541
# Max Temp      541
# Humidity      541
# Cloudiness    541
# Wind Speed    541
# Country       541
# Date          541
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             avarua -21.2078 -159.7750    299.18        78          75
# 1          grytviken -54.2811  -36.5092    270.70        78          30
# 2              leava -14.3000 -178.1667    301.48        77          99
# 3        yellowknife  62.4560 -114.3525    280.60        68          40
# 4  port-aux-francais -49.3500   70.2167    276.60        76          97
#
#    Wind Speed Country        Date
# 0        2.57      CK  1715549655
# 1        5.88      GS  1715549655
# 2       11.78      WF  1715549655
# 3        7.72      CA  1715549656
# 4       10.39      TF  1715549656

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                   avarua -21.2078 -159.7750    299.18        78          75
# 1                grytviken -54.2811  -36.5092    270.70        78          30
# 2                    leava -14.3000 -178.1667    301.48        77          99
# 3              yellowknife  62.4560 -114.3525    280.60        68          40
# 4        port-aux-francais -49.3500   70.2167    276.60        76          97
#
#          Wind Speed Country        Date
# City_ID
# 0              2.57      CK  1715549655
# 1              5.88      GS  1715549655
# 2             11.78      WF  1715549655
# 3              7.72      CA  1715549656
# 4             10.39      TF  1715549656

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
latitudes = [city['Lat'] for city in city_data]
max_temperatures = [city['Max Temp'] for city in city_data]
plt.figure(figsize=(8, 6))
plt.scatter(latitudes, max_temperatures, marker='o')

# Incorporate the other graph properties
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (°F)')
plt.grid(True)

# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
humidity = [city['Humidity'] for city in city_data]
plt.figure(figsize=(8, 6))
plt.scatter(latitudes, humidity, marker='o')

# Incorporate the other graph properties
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.grid(True)

# Save the figure
plt.savefig("Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
cloudliness = [city['Cloudiness'] for city in city_data]
plt.figure(figsize=(8, 6))
plt.scatter(latitudes, humidity, marker='o')

# Incorporate the other graph properties
plt.title('City Latitude vs. Cloudliness')
plt.xlabel('Latitude')
plt.ylabel('Cloudliness')
plt.grid(True)

# Save the figure
plt.savefig("Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
wind_speed = [city['Wind Speed'] for city in city_data]
plt.figure(figsize=(8, 6))
plt.scatter(latitudes, wind_speed, marker='o')

# Incorporate the other graph properties
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid(True)

# Save the figure
plt.savefig("Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x, y, xlabel, ylabel, title):
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    regress_values = slope * x + intercept
    plt.scatter(x, y, marker='o')
    plt.plot(x, regress_values, 'r-', label='Linear Regression')
    line = f'y = {slope:.2f}x + {intercept:.2f}'
    plt.annotate(line, (np.mean(x), np.mean(y)), fontsize=12, color='red')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
    print(f"The r-value is: {r_value}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3             yellowknife  62.4560 -114.3525    280.60        68          40
# 5                 college  64.8569 -147.8028    287.29        34          75
# 7              natitingou  10.3042    1.3796    299.59        70          66
# 8               vorgashor  67.5833   63.9500    264.71        95          84
# 9        praia da vitoria  38.7333  -27.0667    293.29        77          75
#
#          Wind Speed Country        Date
# City_ID
# 3              7.72      CA  1715549656
# 5              2.06      US  1715549656
# 7              0.43      BJ  1715549656
# 8              5.82      RU  1715549657
# 9              3.94      PT  1715549657

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                   avarua -21.2078 -159.7750    299.18        78          75
# 1                grytviken -54.2811  -36.5092    270.70        78          30
# 2                    leava -14.3000 -178.1667    301.48        77          99
# 4        port-aux-francais -49.3500   70.2167    276.60        76          97
# 6           puerto natales -51.7236  -72.4875    273.40        80           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.57      CK  1715549655
# 1              5.88      GS  1715549655
# 2             11.78      WF  1715549655
# 4             10.39      TF  1715549656
# 6              1.03      CL  1715549656

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
northern_latitudes = northern_hemi_df['Lat']
northern_max_temperatures = northern_hemi_df['Max Temp']

plot_linear_regression(northern_latitudes, northern_max_temperatures, 'Latitude', 'Max Temperature (°F)', 'Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
# Out:
# The r-value is: -0.8343074703647837

# %%
# Linear regression on Southern Hemisphere
southern_latitudes = southern_hemi_df['Lat']
southern_max_temperatures = southern_hemi_df['Max Temp']

plot_linear_regression(southern_latitudes, southern_max_temperatures, 'Latitude', 'Max Temperature (°F)', 'Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
# Out:
# The r-value is: 0.8310332390629911

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_latitudes = northern_hemi_df['Lat']
northern_humidity = northern_hemi_df['Humidity']

plot_linear_regression(northern_latitudes, northern_humidity, 'Latitude', 'Humidity', 'Northern Hemisphere - Humidity vs. Latitude Linear Regression')
# Out:
# The r-value is: 0.1301536400341262

# %%
# Southern Hemisphere
southern_latitudes = southern_hemi_df['Lat']
southern_humidity = southern_hemi_df['Humidity']

plot_linear_regression(southern_latitudes, southern_humidity, 'Latitude', 'Humidity', 'Southern Hemisphere - Humidity vs. Latitude Linear Regression')
# Out:
# The r-value is: 0.12658485047976617

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_latitudes = northern_hemi_df['Lat']
northern_cloudiness = northern_hemi_df['Cloudiness']

plot_linear_regression(northern_latitudes, northern_cloudiness, 'Latitude', 'Cloudiness', 'Northern Hemisphere - Cloudiness vs. Latitude Linear Regression')
# Out:
# The r-value is: 0.06363287480761178

# %%
# Southern Hemisphere
southern_latitudes = southern_hemi_df['Lat']
southern_cloudiness = southern_hemi_df['Cloudiness']

plot_linear_regression(southern_latitudes, southern_cloudiness, 'Latitude', 'Cloudiness', 'Southern Hemisphere - Cloudiness vs. Latitude Linear Regression')
# Out:
# The r-value is: 0.07382943715036157

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_latitudes = northern_hemi_df['Lat']
northern_wind_speed = northern_hemi_df['Wind Speed']

plot_linear_regression(northern_latitudes, northern_wind_speed, 'Latitude', 'Wind Speed', 'Northern Hemisphere - Wind Speed vs. Latitude Linear Regression')
# Out:
# The r-value is: -0.05159479355052316

# %%
# Southern Hemisphere
southern_latitudes = southern_hemi_df['Lat']
southern_wind_speed = southern_hemi_df['Wind Speed']

plot_linear_regression(southern_latitudes, southern_wind_speed, 'Latitude', 'Wind Speed', 'Southern Hemisphere - Wind Speed vs. Latitude Linear Regression')
# Out:
# The r-value is: -0.11382468812481919

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
